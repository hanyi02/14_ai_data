# %%
#정수형
a=123
b=-170
c=0

type(a)
# Out:
# int

# %%
# 실수형

a= 1.2E10
b= 4.2E-10
c= 3.14

type(c)
a #a만 써도 print 안 써도 출력가능, 주피터는 마지막 줄만 출력함
type(a)
# Out:
# float

# %%
# 8진수, 16진수

a= 0o177 #8**2 + 8*7 + 7

a
# Out:
# 127

# %%
#16진수

a= 0x8ff #16**2*8 + 16*8 + 15
a
# Out:
# 2303

# %%
# 사칙연산

a= 3
b= 4
a+b
a-b
a*c
a/b
a%b
# Out:
# 3

# %%
# 제곱
a=3
b=4
a** b
# Out:
# 81

# %%
16 ** 1/2
# Out:
# 8.0

# %%
# 나눗셈 후 나머지를 반환하는 %연산자

7%3
# Out:
# 1

# %%
# 나눗셈 후 몫을 반환하는 연산자
7//3
# Out:
# 2

# %%
7/3
# Out:
# 2.3333333333333335

# %%
# 복합연산자
a= 1
a +=1 #a= a+1
a -=1 #a= a-1
a /=1 #a= a/1
a *=1 #a= a*1
print(a)
# Out:
# 2
