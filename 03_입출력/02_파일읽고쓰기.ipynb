# %%
# 파일 생성하기

f=open("새파일.txt", "w")
f.close()

# %%
f=open("새파일2.txt", "w")

for i in range(1, 11):
    data= (f" {i} 번쨰 줄입니다. \n")
    f.write(data)

f.close()

# 안깨진 문자 보려면 utf 해야 인코딩/ 디코딩 오류 없음
